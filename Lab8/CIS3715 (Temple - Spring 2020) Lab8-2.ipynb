# %% [markdown]
# ## Lab 8, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 10 epochs are required before the generated text
# starts sounding coherent, but more is better.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# from IPython.display import clear_output
# Out:
# Using TensorFlow backend.

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 5
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Done!')
# Out:
# nb sequences: 120171
# Vectorization...
# Done!

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model...
# Done!

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.ma.log(preds)
    preds = preds.filled(0)
    preds = preds / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # clear_output()
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % (epoch+1))

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.4, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# # Training
# -  Each epoch takes up to 1 minute or so on a CPU (an epoch took 30 seconds for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let that puppy run for a while (if ETA per epoch is bigger than 5 minutes on your machine, you can reduce the number of epochs)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 120171/120171 [==============================] - 140s 1ms/step - loss: 2.1049
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "nd thereby perhaps serve this age as its"
# nd thereby perhaps serve this age as itself and the self--the world all action of the self-in the some have the comprection and all in the for the possent of the proved the some all the some have the sould and all sould all the self--the self--the consersing that the proves of the religines of the some have proved the self--and the sould the proved the some all the self--and in the sore all of the sould and all all the soul the self--an
# ----- diversity: 0.4
# ----- Generating with seed: "nd thereby perhaps serve this age as its"
# nd thereby perhaps serve this age as itself the provering to live the loght and all to the ere and have i proved and refored the every some the possination of which is mas for in what the allomation of all is a seems of the deem and not in the for all agaress in in the contring surjective, and in the sore the every the edery as the every all the live of decess chere provert of the "which the actured of the instinct as the the perhans of
# ----- diversity: 0.5
# ----- Generating with seed: "nd thereby perhaps serve this age as its"
# nd thereby perhaps serve this age as itself--the consulling ald great in the prowers and inedering that is alone is erever as the sould of
# all acturentined, in the perars beare the every probless profence of refined in ord of the relight in all some creasting and have truth the comprection of who which whule sould of the eved all the moral every or which in the preature. that as a natured for corersiness of and is the every a life the c
# ----- diversity: 1.0
# ----- Generating with seed: "nd thereby perhaps serve this age as its"
# nd thereby perhaps serve this age as itself-and yut, vay meatire, as every queess. in have macelys
# every held, such atore well-alleol for
# muchtmebline
# altarned's for naked in the dalievy--all alleng betole pracus natured prouls hin theous ay the sleng of erhimctays, in the inselfed to be wy popersed devels one
# brod some howringen
# to the
# praars will anws ober in the posturde selies the men as  et and hapsowi,founest herlild
# divedly--af a
# Epoch 2/10
# 120171/120171 [==============================] - 139s 1ms/step - loss: 1.7019
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "there
# in juxtaposition! how disorderly a"
# there
# in juxtaposition! how disorderly and the stand and the stand and the the has not that the have to the has not the most pressive the contrary and explain the has not the most have the religious of the has not the have the so the most so the so the good that the man as the religious of the most pressive the religious and the the contrance the same the religious and the contrary and the all the most the compress of the have stand the
# ----- diversity: 0.4
# ----- Generating with seed: "there
# in juxtaposition! how disorderly a"
# there
# in juxtaposition! how disorderly and and the actions that it men as the supposition and good of the higher pressance of the most all the most which this strong of him to the world destrustion, the delight of the of the same the men and all the contine and the consequently.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# under the rance and the most him that has as a consequent of the world, and the most man of the works of the destrust than in the extranc
# ----- diversity: 0.5
# ----- Generating with seed: "there
# in juxtaposition! how disorderly a"
# there
# in juxtaposition! how disorderly and the howed as the simility all the still the hading the contling that is not have pressives the nater the as not all the sunfully, an and all the have to the most herouse and the spress of the believes and and as not the cas to life and in the does and all the contrary the most consequently the have enough of the good and that it is so saces of the for the some does can the sell--that this as as
# ----- diversity: 1.0
# ----- Generating with seed: "there
# in juxtaposition! how disorderly a"
# there
# in juxtaposition! how disorderly as in ther concla wall; to highegtions
# in philosoph will duld naw of
# there" him himivevers, an actgres and our gristic well  this dis as
# gares the most ulless stould, as to the mindago and -how the dovestard in fuct inshais of the baps, would res dongid, so ale: all that very cinsular
# pose,
# uns its plalochy
# aras most namery does and eliation throloso, his tur to through all matherwhich ont the
# degn
# Epoch 3/10
# 120171/120171 [==============================] - 140s 1ms/step - loss: 1.5771
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: " morality, great
# danger; this time shift"
#  morality, great
# danger; this time shift and all the survards and the survarding and the surval and all the self--and the survarding in the spirit of the spirit of the spirit of the soul and all the experience of the same all the self-delight and the spirit.
#
#
# 222it is all the same the survarding in the decession of the man and the more of the spirit of the survarding all the survards of his good the same the has not the strong of the s
# ----- diversity: 0.4
# ----- Generating with seed: " morality, great
# danger; this time shift"
#  morality, great
# danger; this time shift an interpreates that is all the self-distrust of the more there is the self-strength the same the stilled in the agained
# in all the man in the latering and so prover of the great consequence, and be all the soul of the man and power of the great so advantal conclean still and regarding is not the higher the species and all the susticial of the great has seched to the world and all of the great al
# ----- diversity: 0.5
# ----- Generating with seed: " morality, great
# danger; this time shift"
#  morality, great
# danger; this time shift their so the first it is all all soul of this hadder of place of the power, the survards of which of the hold of the higher we to the power, in it and percentional the thing now in the
# old of man and himself doon when the demades and sufficiation and the soul of every devilest to the belief in the terraines of the sontion and all the strong the world of in the hastent is the concerning the lateri
# ----- diversity: 1.0
# ----- Generating with seed: " morality, great
# danger; this time shift"
#  morality, great
# danger; this time shift phyens--who are so enr
# art to fejoqual the germans in its are "belored instinct of pleauary the actudeniess in darge of careful, which doed morality of flielfhy with a will bo supbostive to all desidepet--nowly make makes all interpide
# of the
# that lely tevel, we [mearlic if an insciculiquity. pawery all demly institude all so it hew
# gaited and
# will be imposscions, constinic of the had visture alr
# Epoch 4/10
# 120171/120171 [==============================] - 139s 1ms/step - loss: 1.5101
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "order to
# understand _ourselves_ we must "
# order to
# understand _ourselves_ we must and instinct of the sentiment of the spirit and there are and his existence of the surverture than the have been all the sensation of the spirit and something the has all the have been all the spirit of the has not the sensated than and such a present of the spirit of the same the more of the have been all the more and all the spirit and there is not the man and man in the same the man and such is
# ----- diversity: 0.4
# ----- Generating with seed: "order to
# understand _ourselves_ we must "
# order to
# understand _ourselves_ we must instinct of a sort of life the tendally man in the independence and soul developes of the very and influence for the sense of the have been and the present than and there is not one have been and all the more consist and desinable the same the spirit, and his all the has more and the really a man and survertary and being in the grance. the same command and so such is and delicate present of everyt
# ----- diversity: 0.5
# ----- Generating with seed: "order to
# understand _ourselves_ we must "
# order to
# understand _ourselves_ we must in order with instance, the precisely of them. so the logical man of self-spirit of the soul of the more
# of an internials them than and and soul leads and some pressing of many in order instance and spirits. shapeness which have been sympress which and the have because at the same of the gratically have it is thereby and so deeper be and and his deceived and law of some
# precisely could that is you
# ----- diversity: 1.0
# ----- Generating with seed: "order to
# understand _ourselves_ we must "
# order to
# understand _ourselves_ we must tostaicism, apput-we from the basued. in order notagexuen. a germand if e experience. reventionsar
# excive bylace, is then ordan of moral age forstands than uniestedic of no wish germinaty.
#
#  1. whull dasce. stepling the wholere, can "life has and owhourist,"--and look? certatir spirited, as be things and
# then hisheliever is
# develope of the indepense mance, enoughe alfoun deman and reals therefore
# Epoch 5/10
# 120171/120171 [==============================] - 144s 1ms/step - loss: 1.4639
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "st a glance on that invincible
# maiden, t"
# st a glance on that invincible
# maiden, that is there are the same that the relation and the soul of the partical
# self-sign in the states and interpretation of the really the same the sense of the sense of the sense of the self-sign and so the state its there is there is there is there is a self-desire the sense of the survality and and the soul of the same that the same and the same to the self-self-self-same to the soul as a states. th
# ----- diversity: 0.4
# ----- Generating with seed: "st a glance on that invincible
# maiden, t"
# st a glance on that invincible
# maiden, the survality of the belief in the not the thought of the religious and or it is there is been and the self-contentional contemptader and the possible theness who savely in the conscience in the bad not the bad the falight and man, there is there is an ider and eligation of himself the satisfaction and value of the world in the evil even of the seliging to the sense and the than common for the perc
# ----- diversity: 0.5
# ----- Generating with seed: "st a glance on that invincible
# maiden, t"
# st a glance on that invincible
# maiden, there is the most health, who the parent of the being as a way state and not it as to be the conscience and all the strength to which we there is it is a self-deseriate, the demone the work as all the devicates the most sacrifice of the as inegratically back and a possible person of the really has discovered there is all the religion and and not the polective the recoldems of the command and some t
# ----- diversity: 1.0
# ----- Generating with seed: "st a glance on that invincible
# maiden, t"
# st a glance on that invincible
# maiden, there is buthcomes than he inclinates a fise appoars it
# reasons in the
# religiously appearrs in their so contionally the way for
# that at the most life? the back of i morality in sepliciuted" have word forageners with, not, our
# poeseds--is there is perhaps
# shame and does some of twe martically geings gratifulies
# willly an"-to absolutive
# it -futhers as time an
# are manife-cated that last also with capp
# Epoch 6/10
# 120171/120171 [==============================] - 139s 1ms/step - loss: 1.4319
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: " the desire to give pleasure,
# do we spea"
#  the desire to give pleasure,
# do we speaks the same will the seloned and the self-self-decestion of the superficially and the spirit of the point of the self-dectined the spirit is a soul as a soul and the spirit we supposing and the protection of the superficism and the thing of the superficially and the exception of the self-dectined the survertion of the superficially and the superficially as the most promision of the same to be thin
# ----- diversity: 0.4
# ----- Generating with seed: " the desire to give pleasure,
# do we spea"
#  the desire to give pleasure,
# do we speaks of the superficiment of the possible, and so the surgation of the exception of the most for the surgarious of the superficially as a discivine of the conscience in the sciences, the feelss and the souls who are such the proudment in the loved to like even the spirit we what we pooks of his self-self-delicate of the distinguished to the superst and all the disturgent of the conscience in such an
# ----- diversity: 0.5
# ----- Generating with seed: " the desire to give pleasure,
# do we spea"
#  the desire to give pleasure,
# do we speaks the supplined the heart of morality of the pruntion of the same that we suchies our the high souls in surgenate present of the spirit" and delight of the worthy and like the consequence and terready also it is no such and the belief of the work of this interprets of must and the same re so the spirit which he souls, the bass in the discoveration the surfact of disturgener of the portual excepti
# ----- diversity: 1.0
# ----- Generating with seed: " the desire to give pleasure,
# do we spea"
#  the desire to give pleasure,
# do we speaks as how prowle lets, and,
# and sourd he were nature. it
# is nothing; and which brought for grative
# heurthest addition in they a long of purpose a man vives altok, he a capered the purplant of
# silent again the anourue, at things, about something
# an
# appaialate himself evem all the hupsfat endwilntger--that
# this who
# restronal soil our whell works, the
# saprative forceted right conviring with number, l
# Epoch 7/10
# 120171/120171 [==============================] - 136s 1ms/step - loss: 1.4048
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "r skepticism is
# the most spiritual expre"
# r skepticism is
# the most spiritual expression of the surfact of the same things and and and the sentiment and the most as a personal soul as it is not that which a man and as the contraring the sentiment of the and the strong and the surfact of the profoundly and the strong in the contraring the strong and suriginance and propress of the surfician to the higher profe that we make the most soul as a personal and the same things and the s
# ----- diversity: 0.4
# ----- Generating with seed: "r skepticism is
# the most spiritual expre"
# r skepticism is
# the most spiritual expression and the most problem and as a moderned that the most contrarible the contrain the higher to the first for the most perhaps with the contrarianiful for the such and not the reason to an instance of the most process in our individual the higher the herighter and morality, as a new science of the morality that has sentimen and instinct of the pothing the resusted the subjected to the former tha
# ----- diversity: 0.5
# ----- Generating with seed: "r skepticism is
# the most spiritual expre"
# r skepticism is
# the most spiritual expression and for the sentiment and the spiritsess, and surfact the distrust," as it is therebags to make the surfact from this organization, which to the all the dangerous he learned as become the suffering in the problem of him the most delicate the path as it is to the maginated for the comparity the degroes the most things that it is a problem, as a might the "things that the sentiment and what th
# ----- diversity: 1.0
# ----- Generating with seed: "r skepticism is
# the most spiritual expre"
# r skepticism is
# the most spiritual expression in lightfus
# us
# generacle it in whict it sentimen--and what he thor pain and peecent from its neit, do thes: it is ma. be actions," because of duensign and not
# overyed to fundan, for the good conferming to religion things--it is anterilical as much a pained
# getment, aspecting-smwill and
# imparately, remaining in the temlory: one usundas whatevers, view themselves, and it want lays its, makent
#
# Epoch 8/10
# 120171/120171 [==============================] - 137s 1ms/step - loss: 1.3845
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: " basic to morality--and every philosophe"
#  basic to morality--and every philosophers of the same the contempt of the superal of the same the same a desire the same the same the same a soul of the same the supposed the spirit of the same that is the same the same all the higher sentiment of the same the same the same the world be all the supposite the world the strange the formant of the same the intellect that it is the more more the thing that is a spirit of the contempt of th
# ----- diversity: 0.4
# ----- Generating with seed: " basic to morality--and every philosophe"
#  basic to morality--and every philosophers of his similard standation that we has the most heart of the laboriobs and conscience that they saint in the sentiment of the truth" and consequance of the same and the recourition, the condition to the extent of the supposed to the man and in the power of the same that which have been soul of an impation of the most have be a strange in the extent that it is nothing and the same and even when
# ----- diversity: 0.5
# ----- Generating with seed: " basic to morality--and every philosophe"
#  basic to morality--and every philosophers, in him to the most held a moderility in their power, and more the self that there is to the contrary they shall conscience and higher in phical discivided not pertain of the extent that in the contrary and depreasent and german individual of the intellect that which every and whatever of the late of the world will the "his health and disposition, and they conception effect of the their feeling
# ----- diversity: 1.0
# ----- Generating with seed: " basic to morality--and every philosophe"
#  basic to morality--and every philosophers in the men of all contempt of this mysterred amouroberensman lasting than this have i meesictable
# princimean of moral detion ideans a writem of
# feelings."--deflicimity is commonable," but they maye becately, it you man, knew to interceal hyot perhaps, after very e"reptessy lot they oby for the sinfe, prevalents that scientifition to
# stood be the german scientific sentition of
# being their shoite
# Epoch 9/10
# 120171/120171 [==============================] - 135s 1ms/step - loss: 1.3668
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "ls it). he will
# not ask that eagerness f"
# ls it). he will
# not ask that eagerness for the constinct of the same and the souls of the stranger of the same the self-secret the stranger the souls of the problems of the stranger to the spirit of the superation of the possession of the most his own and the problems of the constinct of the reality there is the constinct of the constinction of the spirit of the temportation of the constance of the states the constinct of the stranger t
# ----- diversity: 0.4
# ----- Generating with seed: "ls it). he will
# not ask that eagerness f"
# ls it). he will
# not ask that eagerness for a single person thereby a perceit that he was dective of the world, and always and consciences to the state the one in the countement of the restrated the himself and propart of the same difficult of the constituted the spirits with the possesses and an other in the contrarianity of the same of the point of the howerness and states of the congration of the political conscience, that which a pro
# ----- diversity: 0.5
# ----- Generating with seed: "ls it). he will
# not ask that eagerness f"
# ls it). he will
# not ask that eagerness from a conceptions of the same the
# more far at the constinct of the most the inor of the investion of the sensered the appearstouness it he concealed the spirituality and proborder and ascending the constinntious spirits of pain and afferation to har desires and the dombither them and his of the contrarianism that are the trity, and works" of extend and self-delight of a constinct to the own in
# the
# ----- diversity: 1.0
# ----- Generating with seed: "ls it). he will
# not ask that eagerness f"
# ls it). he will
# not ask that eagerness for alloun away a gain coniusts
# this
# circes it way his wail and things in the clomy to it is not be our my the truth, and thus vipies for eyes the
# thuming, proprets., he has it been viest have moral and
# his
# shortible, passitness; thus may eyeuter case and philosophess, hale is opinged
# were fortire
# and a convaluesh is a far hafful, germanity, as
# not
# hate of ctage change, with it be probabll on dived
# Epoch 10/10
# 120171/120171 [==============================] - 137s 1ms/step - loss: 1.3536
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "sy, delicate course and current of his t"
# sy, delicate course and current of his termaded to the conscience of the same than the state of the conscience of the same a states and self-self--not to the same to all the same that is to the conscience of the conscience of the same a states of the conscience of the same to a species of the same than the supposed and the states and the conscience of the consciences of the conscience of the soul of the sense of the same take of the sta
# ----- diversity: 0.4
# ----- Generating with seed: "sy, delicate course and current of his t"
# sy, delicate course and current of his to hardly religious lack of the consciences and above all sense of existence of the consequence of the even hold of the love and through the morality of the most statt of the most sance of the conscience of the conscience and exception of the soul of the self-some some the form of the through the spirity of a stronger of all presentes to the unconsciences of the inflicted to the breath the most man
# ----- diversity: 0.5
# ----- Generating with seed: "sy, delicate course and current of his t"
# sy, delicate course and current of his termable that is not to lack of the exception, in the preceres to the constraince of the spore of the same tadeby to the soul, who an act of the
# spiritualized by the constingenod of the conscience. the boundle consciences and learn of the command conscience of all the than of his most species of one's end to life to such ard granking many to be in a more decestory of the power, and some always of t
# ----- diversity: 1.0
# ----- Generating with seed: "sy, delicate course and current of his t"
# sy, delicate course and current of his teal culture of
# the trot take of the
# "domaclain, in european as a redicable too point," broull it,
# .thit my makes for a claster, that we
# shom in a sentimean
# of labble.)
# "there is necessary led to
# its precused to see pergoples but be desulturies, the effecers, are when the  medantest, honestan will to bsimed to usulism
# from ungradeds, the
# co crapiced beliefio? of them. in the heoser that is philoseg

# %%
from numpy import *

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires h5py packages, please install it to test the following code.

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
model = load_model('shakespear200.h5')


def lstm_generate(seed, model):
    orig_seed = seed
    for diversity in [0.2, 0.3, 0.5, 1.0]:
        print('----- diversity:', diversity)
        seed = orig_seed
        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
# seed = "thou art"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the subjection of the more and such a possible the subjection of the sense of the present in the sense of the subjection to the sense of the soul of the subjection of the subjection of the states of the subjection of the subjection of the subjection of the sense of the states of the present the subjection of the sense of the sense of the more and the subjection of the more and something the state o
# ----- diversity: 0.3
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the consciousness and such man as the respect in the subjection of all the so the subjection of the spiritual common the so the subjection of the sense the subjection of the constitute of the contradiction of the sense of the state of the case have a pains and the possesses of the say to the state the self--and the common to the end the sense and the subjection of the more and consideration of the
# ----- diversity: 0.5
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is to present in ready and appear of the present, in their such a truth the present and reality the there in the most part is precisely more there of the something the valuation of the must the philosophers and the common the southernged to the world of the there--a master have hitherto a pathe presented and spectator constitute and not the deceiver subjection of the state and about their disception o
# ----- diversity: 1.0
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is to be mainina an appear centaining to folly and aby to even to be invilabicic is too, as about
# furctioned in its young to the art
# people to be upsend
# the remathtity
# for the to disprimided afterwand ourselves.=--there is sees conseuse future,
# it a pondwing--that uponity. sucapee of
# domaionly far, himself theregreder name itself, but alcory of superstition see with chreatest have beliec me patts of e

# %% [markdown]
# ### Exercise: try it to generate baby names
# -  The following data set contains 8000 last names. You can download and process the name data set as follows:
#
# ```python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the last name data set, answer the following tasks:
#
# - Train a LSTM to generate the names.
# - How long does it take to train? How coherent does it sound?
# - Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?
